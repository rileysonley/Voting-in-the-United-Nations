# %%
# Import libraries
import pandas as p

# %%
# creating variables for each clustered dataframe from k-means
df1 = pd.read_csv('clustered_unga4625.csv')
df2 = pd.read_csv('clustered_unga9125.csv')
df3 = pd.read_csv('clustered_unga4691.csv')

# %%
# Concatenate data
df_concat = pd.concat([df1, df2, df3])

# %%
# Remove unwanted column
df_concat = df_concat.drop(columns=['Unnamed: 0'])

# %%
# Check dataframe
df_concat
# Out:
#                                  name country_code  pct_agreement_w_usa  \
# 0                             ANDORRA          AND                69.27
# 1                           AUSTRALIA          AUS                65.26
# 2                             AUSTRIA          AUT                63.57
# 3                             BELGIUM          BEL                72.45
# 4              BOSNIA AND HERZEGOVINA          BIH                55.61
# ..                                ...          ...                  ...
# 166                   SOLOMON ISLANDS          SLB                19.10
# 167                       EL SALVADOR          SLV                45.13
# 168                            SWEDEN          SWE                60.01
# 169                     UNITED STATES          USA               100.00
# 170  SAINT VINCENT AND THE GRENADINES          VCT                20.86
#
#      pct_agreement_w_china  pct_agreement_w_russia  cluster     period  \
# ...

# %%
# Save csv to files 
# This is the data used for the Tableau dashboard
df_concat.to_csv('un_pctagree_data.csv')
